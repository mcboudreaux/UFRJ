# %% [markdown]
# Maria Carolina Boudreaux Ramirez Deleito
#
#
# Matheus Pugliesi

# %%
import random

def f(t, y0):
    y = -0.1 * y0

    return y

# Definição das variáveis
t0 = 0
y0 = 1.0
#h = random.random()  # h aleatório entre 0 e 1
h = round(random.random()) # h aleatório 0 ou 1
n = 5

y = y0

for i in range(n):
    t = t0 + i * h
    y = y + h * f(t, y)

    print("y:", y)
# Out:
# y: 0.9
# y: 0.81
# y: 0.7290000000000001
# y: 0.6561000000000001
# y: 0.5904900000000001
